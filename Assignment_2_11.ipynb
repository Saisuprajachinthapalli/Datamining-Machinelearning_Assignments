# %%
import numpy as np
import matplotlib.pyplot as plt

no_x=100
x = np.linspace(0, 1, no_x)

eps=0.2
y = 1 + x + eps * np.random.random(size=len(x))

X = np.column_stack((np.ones(no_x), x))
y = y.reshape(-1, 1)

print("X shape:", X.shape)
print("y shape:", y.shape)


# 2) compute the coefficient of linear regression line

import numpy as np
import matplotlib.pyplot as plt

X = np.array([[1,1], [1,2], [1,3]])
y = np.array([[3], [6], [14]])

Xt = X.transpose()
XtX = np.dot(Xt, X)
XtX_inv = np.linalg.inv(XtX)
XtY = np.dot(Xt, y)
coeff = np.dot(XtX_inv, XtY)

print('--------------------------------------------------------------------')

print("Coefficient values:", coeff)

print('--------------------------------------------------------------------')

plt.scatter(X[:, 1], y, color='blue')
plt.plot(X, np.dot(X, coeff), color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.show()

print('--------------------------------------------------------------------')

x_pred = 0.8
y_pred = np.dot(np.array([[1, x_pred]]), coeff)
print("Predicted y value for x = 0.8:", y_pred)

print('--------------------------------------------------------------------')

# 2) (Refer to p. 22 in the slides.) Implement linear regression using a library.
import numpy as np
import matplotlib.pyplot as plt

no_x=100
x = np.linspace(0, 1, no_x)

eps=0.2
y = 1 + x + eps * np.random.random(size=len(x))

X = np.column_stack((np.ones(no_x), x))
y = y.reshape(-1, 1)
w = np.linalg.inv(X.T @ X) @ X.T @ y
print("The coefficients are:", w.flatten())

print('--------------------------------------------------------------------')
plt.plot(x, y, 'o')
plt.plot(x, X @ w, 'r')
plt.show()

print('--------------------------------------------------------------------')

x_new = np.array([1, 0.8])
y_pred = x_new @ w
print("The prediction of y for x=0.8 is:", y_pred[0])

print('--------------------------------------------------------------------')

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
print("The coefficients are:", model.coef_.flatten(), model.intercept_)
y_pred2 = model.predict(np.array([1, 0.8]).reshape(1, -1))
# Out:
# X shape: (100, 2)
# y shape: (100, 1)
# --------------------------------------------------------------------
# Coefficient values: [[-3.33333333]
#  [ 5.5       ]]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Predicted y value for x = 0.8: [[1.06666667]]
# --------------------------------------------------------------------
# The coefficients are: [1.08885078 1.01286927]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# The prediction of y for x=0.8 is: 1.899146190137584
# --------------------------------------------------------------------
# The coefficients are: [0.         1.01286927] [1.08885078]
